# %%
import zipfile
import os
import numpy as np
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.3f' % x)
import boto3
import pandas as pd
from io import BytesIO
from io import StringIO
import seaborn as sns
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score

# %%
# Initialize S3 client
s3 = boto3.client('s3')

# Function to load data 
bucket_name = 'ml-stack-759578648427-us-west-2'

def from_s3(bucket_name, file_name):
    response = s3.get_object(Bucket=bucket_name, Key=file_name)
    ext = os.path.splitext(file_name)[1]
    if ext == '.gz':
        data = pd.read_csv(BytesIO(response['Body'].read()), compression='gzip')
    elif ext == '.csv':
        data = pd.read_csv(BytesIO(response['Body'].read()))
    else:
        data = pd.read_excel(BytesIO(response['Body'].read()), sheet_name='DX_to_CCSR_Mapping', header=1)
    return data

# %% [markdown]
# # Import Labeled Data

# %%
file_name = 'final_microbiology_df.csv.gz'
df = from_s3(bucket_name, file_name) 
df['charttime'] = pd.to_datetime(df['charttime'])
subjects = df['subject_id'].unique()
df.head()
# Out:
#    subject_id      hadm_id          org_name               ab_name  \
# 0    10000826 20032235.000  ESCHERICHIA COLI            AMPICILLIN
# 1    10000826 20032235.000  ESCHERICHIA COLI  AMPICILLIN/SULBACTAM
# 2    10000826 20032235.000  ESCHERICHIA COLI             CEFAZOLIN
# 3    10000826 20032235.000  ESCHERICHIA COLI              CEFEPIME
# 4    10000826 20032235.000  ESCHERICHIA COLI           CEFTAZIDIME
#
#             charttime interpretation  susceptible_flag
# 0 2146-12-08 22:22:00              S             1.000
# 1 2146-12-08 22:22:00              S             1.000
# 2 2146-12-08 22:22:00              S             1.000
# 3 2146-12-08 22:22:00              S             1.000
# 4 2146-12-08 22:22:00              S             1.000

# %%
# final pairs 
pairs = [('ESCHERICHIA COLI', 'AMPICILLIN'),
 ('ESCHERICHIA COLI', 'AMPICILLIN/SULBACTAM'),
 ('ESCHERICHIA COLI', 'CEFAZOLIN'),
 ('ESCHERICHIA COLI', 'CEFEPIME'),
 ('ESCHERICHIA COLI', 'CEFTAZIDIME'),
 ('ESCHERICHIA COLI', 'CEFTRIAXONE'),
 ('ESCHERICHIA COLI', 'CIPROFLOXACIN'),
 ('ESCHERICHIA COLI', 'GENTAMICIN'),
 ('ESCHERICHIA COLI', 'MEROPENEM'),
 ('ESCHERICHIA COLI', 'NITROFURANTOIN'),
 ('ESCHERICHIA COLI', 'TOBRAMYCIN'),
 ('ESCHERICHIA COLI', 'TRIMETHOPRIM/SULFA'),
 ('PSEUDOMONAS AERUGINOSA', 'CEFEPIME'),
 ('PSEUDOMONAS AERUGINOSA', 'CEFTAZIDIME'),
 ('PSEUDOMONAS AERUGINOSA', 'CIPROFLOXACIN'),
 ('PSEUDOMONAS AERUGINOSA', 'GENTAMICIN'),
 ('PSEUDOMONAS AERUGINOSA', 'MEROPENEM'),
 ('PSEUDOMONAS AERUGINOSA', 'PIPERACILLIN/TAZO'),
 ('PSEUDOMONAS AERUGINOSA', 'TOBRAMYCIN'),
 ('ESCHERICHIA COLI', 'PIPERACILLIN/TAZO'),
 ('KLEBSIELLA PNEUMONIAE', 'AMPICILLIN/SULBACTAM'),
 ('KLEBSIELLA PNEUMONIAE', 'CEFAZOLIN'),
 ('KLEBSIELLA PNEUMONIAE', 'CEFEPIME'),
 ('KLEBSIELLA PNEUMONIAE', 'CEFTAZIDIME'),
 ('KLEBSIELLA PNEUMONIAE', 'CEFTRIAXONE'),
 ('KLEBSIELLA PNEUMONIAE', 'CIPROFLOXACIN'),
 ('KLEBSIELLA PNEUMONIAE', 'GENTAMICIN'),
 ('KLEBSIELLA PNEUMONIAE', 'MEROPENEM'),
 ('KLEBSIELLA PNEUMONIAE', 'NITROFURANTOIN'),
 ('KLEBSIELLA PNEUMONIAE', 'PIPERACILLIN/TAZO'),
 ('KLEBSIELLA PNEUMONIAE', 'TOBRAMYCIN'),
 ('KLEBSIELLA PNEUMONIAE', 'TRIMETHOPRIM/SULFA')]

df = df[df[['org_name', 'ab_name']].apply(tuple, axis=1).isin(pairs)]

# %% [markdown]
# # Majority Classifier - Baseline Metrics

# %%
# get unique org & ab combos 
org_ab_label = df[['org_name', 'ab_name']].drop_duplicates()

# %%
# for each label calculate metrics for majority classifier 
baselines = []

for index, row in org_ab_label.iterrows():
    org = f"{row.org_name}"
    ab = f"{row.ab_name}"
    sub = df.query(f"org_name == '{org}' & ab_name == '{ab}'")
    y_true = sub.susceptible_flag 

    if (y_true.sum() / len(y_true)) > 0.5:
        maj_class = 1
    else:
        maj_class = 0
    
    y_pred = [maj_class] * len(y_true)
    
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    accuracy = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)

    metrics = {'bacteria':org, 'antibiotic':ab, 'accuracy':accuracy, 'precision':precision, 'recall':recall, 'f1_score':f1}
    baselines.append(metrics)
# Out:
# /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
baseline_results = pd.DataFrame(baselines)
baseline_results
# Out:
#                   bacteria            antibiotic  accuracy  precision  recall  \
# 0         ESCHERICHIA COLI            AMPICILLIN     0.504      0.504   1.000
# 1         ESCHERICHIA COLI  AMPICILLIN/SULBACTAM     0.611      0.611   1.000
# 2         ESCHERICHIA COLI             CEFAZOLIN     0.806      0.806   1.000
# 3         ESCHERICHIA COLI              CEFEPIME     0.915      0.915   1.000
# 4         ESCHERICHIA COLI           CEFTAZIDIME     0.921      0.921   1.000
# 5         ESCHERICHIA COLI           CEFTRIAXONE     0.883      0.883   1.000
# 6         ESCHERICHIA COLI         CIPROFLOXACIN     0.732      0.732   1.000
# 7         ESCHERICHIA COLI            GENTAMICIN     0.897      0.897   1.000
# 8         ESCHERICHIA COLI             MEROPENEM     0.999      0.999   1.000
# 9         ESCHERICHIA COLI        NITROFURANTOIN     0.957      0.957   1.000
# 10        ESCHERICHIA COLI     PIPERACILLIN/TAZO     0.986      0.986   1.000
# 11        ESCHERICHIA COLI            TOBRAMYCIN     0.901      0.901   1.000
# 12        ESCHERICHIA COLI    TRIMETHOPRIM/SULFA     0.726      0.726   1.000
# 13   KLEBSIELLA PNEUMONIAE  AMPICILLIN/SULBACTAM     0.771      0.771   1.000
# 14   KLEBSIELLA PNEUMONIAE             CEFAZOLIN     0.834      0.834   1.000
# 15   KLEBSIELLA PNEUMONIAE              CEFEPIME     0.893      0.893   1.000
# 16   KLEBSIELLA PNEUMONIAE           CEFTAZIDIME     0.880      0.880   1.000
# 17   KLEBSIELLA PNEUMONIAE           CEFTRIAXONE     0.868      0.868   1.000
# 18   KLEBSIELLA PNEUMONIAE         CIPROFLOXACIN     0.863      0.863   1.000
# 19   KLEBSIELLA PNEUMONIAE            GENTAMICIN     0.926      0.926   1.000
# 20   KLEBSIELLA PNEUMONIAE             MEROPENEM     0.993      0.993   1.000
# 21   KLEBSIELLA PNEUMONIAE        NITROFURANTOIN     0.687      0.000   0.000
# 22   KLEBSIELLA PNEUMONIAE     PIPERACILLIN/TAZO     0.952      0.952   1.000
# 23   KLEBSIELLA PNEUMONIAE            TOBRAMYCIN     0.898      0.898   1.000
# 24   KLEBSIELLA PNEUMONIAE    TRIMETHOPRIM/SULFA     0.845      0.845   1.000
# 25  PSEUDOMONAS AERUGINOSA              CEFEPIME     0.859      0.859   1.000
# 26  PSEUDOMONAS AERUGINOSA           CEFTAZIDIME     0.847      0.847   1.000
# 27  PSEUDOMONAS AERUGINOSA         CIPROFLOXACIN     0.733      0.733   1.000
# 28  PSEUDOMONAS AERUGINOSA            GENTAMICIN     0.858      0.858   1.000
# 29  PSEUDOMONAS AERUGINOSA             MEROPENEM     0.826      0.826   1.000
# 30  PSEUDOMONAS AERUGINOSA     PIPERACILLIN/TAZO     0.871      0.871   1.000
# 31  PSEUDOMONAS AERUGINOSA            TOBRAMYCIN     0.913      0.913   1.000
#
#     f1_score
# 0      0.670
# 1      0.759
# 2      0.892
# 3      0.956
# 4      0.959
# 5      0.938
# 6      0.846
# 7      0.946
# 8      0.999
# 9      0.978
# 10     0.993
# 11     0.948
# 12     0.841
# 13     0.871
# 14     0.909
# 15     0.943
# 16     0.936
# 17     0.929
# 18     0.927
# 19     0.962
# 20     0.996
# 21     0.000
# 22     0.975
# 23     0.946
# 24     0.916
# 25     0.924
# 26     0.917
# 27     0.846
# 28     0.924
# 29     0.904
# 30     0.931
# 31     0.955
